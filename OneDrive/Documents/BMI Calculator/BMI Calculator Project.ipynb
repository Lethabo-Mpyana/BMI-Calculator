# %% [markdown]
# # BMI Calculator

# %%
#BMI = (weight in pounds * 703) / (height * height)

# %%
print ('Hi, Welcome to the BMI Calculator')

name = input('What is your name and surname?  ')

print(input)
print('Nice to meet you',name)

weight = int(input('What is your weight?  '))
print(weight)

height = int(input('What is your height?  '))
print(height)

BMI =(weight * 703) / (height * height)
print(BMI)
# Out:
# Hi, Welcome to the BMI Calculator
# What is your name and surname?   Lee M
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x000001680DD1DE80>>
# Nice to meet you Lee M
# What is your weight?   69
# 69
# What is your height?   58
# 58
# 14.419441141498217

# %%
#weight

#Under 18.5 -> Underweight
#18.5 - 24.9 -> Normal weight
#25 - 29.9-> Overweight
#30 - 34.9-> Obese
#35 - 39.9-> Severely obese
#40 and over-> Morbidly obese

# %%
if BMI>0:
    if(BMI<=18.5):
        print(name +',you are underweight.')
    elif(BMI<24.9):
        print(name +',you are normal weight.')
    elif(BMI<29.9):
        print(name +',you are overweight.')
    elif(BMI<34.9):
        print(name +',you are obese.')
    elif(BMI<39.9):
        print(name +',you are severly obese.')
    elif(BMI>40):
        print(name +',you are morbidly obese.')
    else:
        print('Enter valid input.')
# Out:
# Lee M,you are underweight.
